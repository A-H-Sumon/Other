# %%
import pandas as pd

# %%
dir = "F:\diabetese-dataset\Diabetesdataupload.xlsx"
df = pd.read_excel(dir)

# %%
df.loc[df['Age'].between(30,35), 'age_group'] = '30-35'
df.loc[df['Age'].between(36,40), 'age_group'] = '35-40'
df.loc[df['Age'].between(41,45), 'age_group'] = '41-45'
df.loc[df['Age'].between(46,50), 'age_group'] = '46-50'
df.loc[df['Age'].between(51,55), 'age_group'] = '51-55'
df.loc[df['Age'].between(56,60), 'age_group'] = '56-60'
df.loc[df['Age'].between(60,65), 'age_group'] = '60-65'
df.loc[df['Age'].between(66,70), 'age_group'] = '66-70'
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden_weight_loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
dff=df.drop('Age', axis='columns')
dff
# Out:
#      Gender Polyuria Polydipsia sudden_weight_loss weakness Polyphagia  \
# 0      Male       No        Yes                 No      Yes         No
# 1      Male       No         No                 No      Yes         No
# 2      Male      Yes         No                 No      Yes        Yes
# 3      Male       No         No                Yes      Yes        Yes
# 4      Male      Yes        Yes                Yes      Yes        Yes
# ..      ...      ...        ...                ...      ...        ...
# 515  Female      Yes        Yes                Yes       No        Yes
# 516  Female      Yes        Yes                Yes      Yes        Yes
# 517  Female      Yes        Yes                Yes      Yes        Yes
# 518  Female       No         No                 No      Yes         No
# 519    Male       No         No                 No       No         No
#
#     Genital_thrush visual_blurring Itching Irritability delayed_healing  \
# ...

# %%
dff['class'].value_counts().plot.pie(autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='class'>

# %%
from sklearn.preprocessing import LabelEncoder
le_class = LabelEncoder()
dff['class'] = le_class.fit_transform(df['class'])

# %%
dff
# Out:
#      Gender Polyuria Polydipsia sudden_weight_loss weakness Polyphagia  \
# 0      Male       No        Yes                 No      Yes         No
# 1      Male       No         No                 No      Yes         No
# 2      Male      Yes         No                 No      Yes        Yes
# 3      Male       No         No                Yes      Yes        Yes
# 4      Male      Yes        Yes                Yes      Yes        Yes
# ..      ...      ...        ...                ...      ...        ...
# 515  Female      Yes        Yes                Yes       No        Yes
# 516  Female      Yes        Yes                Yes      Yes        Yes
# 517  Female      Yes        Yes                Yes      Yes        Yes
# 518  Female       No         No                 No      Yes         No
# 519    Male       No         No                 No       No         No
#
#     Genital_thrush visual_blurring Itching Irritability delayed_healing  \
# ...

# %%
le_Gender = LabelEncoder()
le_Polyuria = LabelEncoder()
le_Polydipsia = LabelEncoder()
le_sudden_weight_loss = LabelEncoder()
le_weakness = LabelEncoder()
le_Polyphagia = LabelEncoder()
le_Genital_thrush = LabelEncoder()
le_visual_blurring = LabelEncoder()
le_Itching = LabelEncoder()
le_Irritability = LabelEncoder()
le_delayed_healing = LabelEncoder()
le_partial_paresis = LabelEncoder()
le_muscle_stiffness = LabelEncoder()
le_Alopecia = LabelEncoder()
le_Obesity	 = LabelEncoder()
le_age_group = LabelEncoder()

# %%
dff['sex'] = le_Gender.fit_transform(dff['Gender'])
dff['polyuria'] = le_Polyuria.fit_transform(dff['Polyuria'])
dff['polydipsia'] = le_Polydipsia.fit_transform(dff['Polydipsia'])
dff['Weight_loss'] = le_sudden_weight_loss.fit_transform(dff['sudden_weight_loss'])
dff['Weakness'] = le_weakness.fit_transform(dff['weakness'])
dff['polyphagia'] = le_Polyphagia.fit_transform(dff['Polyphagia'])
dff['genital_Thrush'] = le_Genital_thrush.fit_transform(dff['Genital_thrush'])
dff['Visual_Blurring'] = le_visual_blurring.fit_transform(dff['visual_blurring'])
dff['itchiness'] = le_Itching.fit_transform(dff['Itching'])
dff['irritation'] = le_Irritability.fit_transform(dff['Irritability'])
dff['late_healing'] = le_delayed_healing.fit_transform(dff['delayed_healing'])
dff['Partial_Paresis'] = le_partial_paresis.fit_transform(dff['partial_paresis'])
dff['Muscle_Stiffness'] = le_muscle_stiffness.fit_transform(dff['muscle_stiffness'])
dff['alopecia'] = le_Alopecia.fit_transform(dff['Alopecia'])
dff['obesity'] = le_Obesity.fit_transform(dff['Obesity'])
dff['age'] = le_age_group.fit_transform(dff['age_group'])

# %%
data=dff.drop(['Gender','Polyuria', 'Polydipsia','sudden_weight_loss','weakness','Polyphagia','Genital_thrush','visual_blurring','Itching','Irritability','delayed_healing','partial_paresis','muscle_stiffness','Alopecia','Obesity','age_group'], axis='columns')

# %%
diabetes = data[['sex','polyuria', 'polydipsia','Weight_loss','Weakness','polyphagia','genital_Thrush','Visual_Blurring','itchiness','irritation','late_healing','Partial_Paresis','Muscle_Stiffness','alopecia','obesity','age','class']]

# %%
diabetes_correlation=diabetes.corr()
print(diabetes_correlation['class'].sort_values(ascending=False))
# Out:
# class               1.000000
# polyuria            0.665922
# polydipsia          0.648734
# Weight_loss         0.436568
# Partial_Paresis     0.432288
# polyphagia          0.342504
# irritation          0.299467
# Visual_Blurring     0.251300
# Weakness            0.243275
# Muscle_Stiffness    0.122474
# genital_Thrush      0.110288
# obesity             0.072173
# late_healing        0.046980
# age                 0.018468
# itchiness          -0.013384
# alopecia           -0.267512
# sex                -0.449233
# Name: class, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,16))
sns.heatmap(diabetes_correlation,annot=True,cmap='Blues',square=True,vmax=0.8)
# Out:
# <AxesSubplot:>

# %%
x = data[['sex','polyuria', 'polydipsia','Weight_loss','Weakness','polyphagia','genital_Thrush','Visual_Blurring','itchiness','irritation','late_healing','Partial_Paresis','Muscle_Stiffness','alopecia','obesity','age']]
y = data['class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size= 0.1)
print(x_train.shape)
print(y_train.shape)
# Out:
# (468, 16)
# (468,)
# (468,)
# (52,)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 0)
x_train_new, y_train_new = sm.fit_resample(x_train, y_train)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix

model= tree.DecisionTreeClassifier()
prediction = model.fit(x_train_new,y_train_new)

# %%
y_pred=model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        21
#            1       0.97      1.00      0.98        31
#
#     accuracy                           0.98        52
#    macro avg       0.98      0.98      0.98        52
# weighted avg       0.98      0.98      0.98        52

# %%
conf_mat = confusion_matrix(y_test,y_pred)
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap="Blues")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
